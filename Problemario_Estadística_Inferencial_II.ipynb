# %% [markdown]
# <a href="https://colab.research.google.com/github/ChristianPro31/code/blob/main/Problemario_Estad%C3%ADstica_Inferencial_II.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Unidad 1. Regresión lineal simple y correlación

# %% [markdown]
# ## Medidas de dispersión
# Suma de los cuadrados de las desviaciones de los valores de $X$ con respecto a su media:
# $$ S_{xx} = \sum_{i=1}^{n} (X_i - \bar{X})^2 $$
# Suma de los productos de las desviaciones de los valores de $X$ y $Y$ con respecto a sus medias:
# $$S_{xy} = \sum_{i=1}^{n} (X_i - \bar{X})(Y_i - \bar{Y})$$
# Suma de los cuadrados de las desviaciones de los valores de $Y$ con respecto a su media:
# $$ S_{yy} = \sum_{i=1}^{n} (Y_i - \bar{Y})^2 $$

# %% [markdown]
# ## Coeficiente de correlación y de determinación
# Coeficiente de correlación de Pearson:
# $$ r = \frac{S_{xy}}{\sqrt{S_{xx} \cdot S_{yy}}} $$
# Coeficiente de determinación:
# $$ r^2 $$

# %% [markdown]
# ## Recta de regresión ajustada
# La regresión lineal ajustada se representa mediante estadísticos:
# $$ \hat{Y} = b_0 + b_1 X $$
# donde $\hat{Y}$ representa el valor de $Y$ obtenido mediante la recta de regresión ajustada (no la verdadera $Y$). Los estadísticos $b_0$ y $b_1$ se calculan de la siguiente manera:
#
# $$b_1 = \frac{S_{xy}}{S_{xx}}$$
#
# $$ b_0 = \bar{Y} - b_1 \bar{X} $$

# %% [markdown]
# ## Cálculo de residuales
# Residuales:
# $$e_i = Y_i - \hat{Y}_i$$

# %% [markdown]
# ## Sumas de cuadrados SS (Sum of Squares)
# Suma de los Cuadrados de los Errores:
# $$ SSE = \sum_{i=1}^{n} (Y_i - \hat{Y}_i)^2 = \sum_{i=1}^n e_i^2$$
# Suma total de cuadrados:
# $$SST = \sum_{i=1}^{n} (Y_i - \bar{Y})^2$$
# Suma de cuadrados de regresión:
# $$SSR = \sum_{i=1}^{n} (\hat{Y_i} - \bar{Y})^2$$
# - SST: Mide la variabilidad total de los datos observados.
# - SSR: Mide la variabilidad de los datos que el modelo de regresión explica.
# - SSE: Mide la variabilidad no explicada por el modelo (es decir, los residuos).

# %% [markdown]
# ## Intervalo de confianza
# Estadístico de prueba _t_:
# $$t = \frac{b_1}{SE(b_1)}$$
# Error estándar de $b_1$:
# $$SE(b_1) = \frac{\sqrt{SSE / (n-2)}}   {\sqrt{S_{xx}} }$$
# o
# $$SE(b_1) = \frac{\sqrt{\sum_{i=1}^{n} (Y_i - \hat{Y}_i)^2  / (n-2)}}   {\sqrt{S_{xx}} }$$
#
# Intervalo de confianza para $b_1$:
# $$b_1 - t_{\alpha/2} \cdot SE(b_1) \lt \beta_1 \lt b_1 + t_{\alpha/2} \cdot SE(b_1)$$
# donde $n$ representa la cantidad de pares de datos.

# %% [markdown]
# ## Comprobación de supuestos
# Comprobar suposiciones:
# - Test de shapiro a los residuales $e_i$: Para comprobar si la distribución es normal sobre la recta.
# - Grafico $X$ vs $Y$: Para observar si los datos soportan la suposición de linealidad.
# - Gráfico de residuales: Para observar si los datos soportan la suposición de linealidad, complementario al coeficiente de correlación
# - Test de Breusch-Pagan: Para detectar heteroscedasticidad en regresion lineal

# %% [markdown]
# Test de Shapiro:<br>
# `from scipy.stats import shapiro`<br>
# Después, se obtiene el valor-p:<br>
# `_, valor_p_sh = shapiro(data)`<br>
# - $H_0$: Los datos siguen una distribución normal
# - $H_1$: Los datos no siguen una distribución normal

# %% [markdown]
# Test de Breusch-Pagan:<br>
# `from statsmodels.stats.api import het_breuschpagan`<br>
# Después, se obtiene el valor-p:<br>
# `_, valor_p_bp, _, _ = het_breuschpagan(residuales, X)`
# - $H_0$: Hay homoscedasticidad
# - $H_1$: Hay heteroscedasticidad

# %% [markdown]
# ## ANOVA en regresión lineal
#
# | Fuente de variación | Suma de cuadrados (SS) | Grados de libertad (df) | Promedio de los cuadrados (MS) | Estadístico F |
# |---------------------|------------------------|--------------------------|--------------------------------|---------------|
# | Regresión  | $ SSR$ | $p$ | $MSR = \frac{SSR}{p}$ | $F = \frac{MSR}{MSE}$|
# | Error | $SSE$| $n - p - 1 $| $MSE = \frac{SSE}{n - p - 1} $|     |
# | Total | $SST $| $n - 1$|             |        |
#
# donde $p$ es el número de parámetros para la recta de regresión ajustada (en la regresión simple $p=1$). Las hipótesis son:
# $$H_0: \beta_1 = 0$$
# $$H_1: \beta_1 \ne 0 $$

# %% [markdown]
# ## Problemario de la Unidad 1

# %% [markdown]
# ### Problema 1
# Un profesor intenta mostrar a sus estudiantes la importancia de los exámenes cortos, aun cuando el 90% de la calificación final esté determinada por los exámenes parciales. Él cree que cuanto más altas sean las calificaciones de los exámenes cortos, más alta será la calificación final. Seleccionó una muestra aleatoria de 15 estudiantes de su clase con los siguientes datos:
#
# | Promedio de exámenes cortos | Promedio final |
# |--------------|--------------|
# | 59 | 64 |
# | 92 | 84 |
# | 72 | 77 |
# | 90 | 80 |
# | 95 | 77 |
# | 87 | 81 |
# | 89 | 80 |
# | 77 | 84 |
# | 76 | 80 |
# | 65 | 69 |
# | 97 | 83 |
# | 42 | 40 |
# | 94 | 78 |
# | 62 | 65 |
# | 91 | 90 |
#
#
#
# 1.   Establesca una variable dependiente ($Y$) y una variable independiente ($X$).
# 2.   Realice un diagrama de dispersión para estos datos.
# 3. ¿Los datos soportan la suposición de linealidad?
# 4. Calcule el coeficiente de correlación e interprete el resultado.
# 5. Calcule el coeficiente de determinación e interprete el resultado.
# 6. Obtenga la recta de regresión ajustada y grafíquelo sobre el gráfico de dispersión.
# 7. Obtenga un intervalo de confianza del 95% para la pendiente de la recta de regresión ajustada ($b_1$)
# 8. Calcule los residuales y trace un nuevo gráfico de dispersión. Comente, ¿Parece que se verifican los supuestos?
# 9. Realice la prueba de Shapiro para los residuales y comente el resultado.
# 10. Realice la prueba de Brausch-Pagan para los residuales y comente el resultado.
# 11. Tres estudiantes sacaron 70, 75 y 84 de calificación. Según la recta de regresión ajustada, ¿cuáles son los resultados esperados para estos tres alumnos?
# 12. Realice una tabla ANOVA e interprete el resultado.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import statsmodels.stats.api as sms
import statsmodels.api as sm
import statsmodels.formula.api as smf
import scipy.stats as stats

x = np.array([59,92,72,90,95,87,89,77,76,65,97,42,94,62,91])
y = np.array([64,84,77,80,77,81,80,84,80,69,83,40,78,65,90])

plt.scatter(x,y)
plt.xlabel("Promedio de exámenes cortos (X)")
plt.ylabel("Promedio final (Y)")
plt.title("Diagrama de dispersión")
plt.grid()
plt.show()

r, pvalue = stats.pearsonr(x, y)
print("Coeficiente de correlación (r): ", r)

x_const = sm.add_constant(x)
modelo = sm.OLS(y, x_const).fit()

print(modelo.summary())
b0 = modelo.params[0]
b1 = modelo.params[1]

print("Ecuación:")
print(f"Y = {b0:.2f} + {b1:.2f}X")

plt.scatter(x, y)
plt.plot(x, b0 + b1*x)
plt.xlabel("X")
plt.ylabel("Y")
plt.title("Regresión lineal")
plt.grid()
plt.show()

conf_int = modelo.conf_int(alpha=0.05)
print("Intervalos de confianza:")
print(conf_int)

residuales = modelo.resid

plt.scatter(x, residuales)
plt.axhline(y=0)
plt.title("Residuales vs X")
plt.grid()
plt.show()

shapiro_test = stats.shapiro(residuales)
print("Shapiro-Wilk:", shapiro_test)

bp_test = sms.het_breuschpagan(residuales, x_const)
print("Breusch-Pagan:", bp_test)

X_new = np.array([70,75,84])
X_new_const = sm.add_constant(X_new)

predicciones = modelo.predict(X_new_const)

print("Predicciones:")
for xi, yi in zip(X_new, predicciones):
    print(f"Para X={xi}, Y estimado={yi:.2f}")


data = pd.DataFrame({'X': x, 'Y': y})
modelo_formula = smf.ols('Y ~ X', data=data).fit()
anova = sm.stats.anova_lm(modelo_formula, typ=2)

print("ANOVA:")
print(anova)
# Out:
# Coeficiente de correlación (r):  0.8646014213752983
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.748
# Model:                            OLS   Adj. R-squared:                  0.728
# Method:                 Least Squares   F-statistic:                     38.49
# Date:                Thu, 16 Apr 2026   Prob (F-statistic):           3.20e-05
# Time:                        16:27:06   Log-Likelihood:                -47.870
# No. Observations:                  15   AIC:                             99.74
# Df Residuals:                      13   BIC:                             101.2
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         24.5268      8.371      2.930      0.012       6.442      42.612
# x1             0.6432      0.104      6.204      0.000       0.419       0.867
# ==============================================================================
# Omnibus:                        0.311   Durbin-Watson:                   1.195
# Prob(Omnibus):                  0.856   Jarque-Bera (JB):                0.448
# Skew:                          -0.241   Prob(JB):                        0.799
# Kurtosis:                       2.304   Cond. No.                         414.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Ecuación:
# Y = 24.53 + 0.64X
# Intervalos de confianza:
# [[ 6.44199691 42.61164624]
#  [ 0.41921868  0.86714104]]
# Shapiro-Wilk: ShapiroResult(statistic=np.float64(0.9731638066576076), pvalue=np.float64(0.901827735700704))
# Breusch-Pagan: (np.float64(1.4477631507186295), np.float64(0.2288872132755837), np.float64(1.3887685972917598), np.float64(0.25973450207912396))
# Predicciones:
# Para X=70, Y estimado=69.55
# Para X=75, Y estimado=72.77
# Para X=84, Y estimado=78.55
# ANOVA:
#                sum_sq    df          F    PR(>F)
# X         1538.228959   1.0  38.492412  0.000032
# Residual   519.504375  13.0        NaN       NaN

# %% [markdown]
# ### Problema 2
# William Hawkins, vicepresidente de personal de la International Motors, trabaja en la relación entre el salario de un trabajador y el porcentaje de ausentismo. Hawkins dividió el intervalo de salarios de International en 12 grados o niveles (1 es el menor grado, 12 el más alto) y después muestreó aleatoriamente a un grupo de trabajadores. Determinó el grado de salario de cada trabajador y el número de días que ese empleado había faltado en los últimos 3 años.
#
# | Categoría de salario | 11 | 10 | 8  | 5  | 9  | 7  | 3  |
# |----------------------|----|----|----|----|----|----|----|
# | Ausencias           | 18 | 17 | 29 | 36 | 11 | 28 | 35 |
#
# | Categoría de salario | 11 | 8  | 7  | 2  | 9  | 8  | 3  |
# |----------------------|----|----|----|----|----|----|----|
# | Ausencias           | 14 | 20 | 32 | 39 | 16 | 31 | 40 |
#
# 1.   Establesca una variable dependiente ($Y$) y una variable independiente ($X$).
# 2.   Realice un diagrama de dispersión para estos datos.
# 3. ¿Los datos soportan la suposición de linealidad?
# 4. Calcule el coeficiente de correlación e interprete el resultado.
# 5. Calcule el coeficiente de determinación e interprete el resultado.
# 6. Obtenga la recta de regresión ajustada y grafíquelo sobre el gráfico de dispersión.
# 7. Obtenga un intervalo de confianza del 95% para la pendiente de la recta de regresión ajustada ($b_1$)
# 8. Calcule los residuales y trace un nuevo gráfico de dispersión. Comente, ¿Parece que se verifican los supuestos?
# 9. Realice la prueba de Shapiro para los residuales y comente el resultado.
# 10. Realice la prueba de Brausch-Pagan para los residuales y comente el resultado.
# 11. Utiliza la recta de regresión para interpolar dos valores y extrapolar uno. Comenta estos resultados.
# 12. Realice una tabla ANOVA e interprete el resultado.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import statsmodels.stats.api as sms
import statsmodels.api as sm
import statsmodels.formula.api as smf
import scipy.stats as stats

x = np.array([11,10,8,5,9,7,3,11,8,7,2,9,8,3])
y = np.array([18,17,29,36,11,28,35,14,20,32,39,16,31,40])

plt.scatter(x,y)
plt.xlabel("Salario")
plt.ylabel("Ausencias")
plt.title("Diagrama de dispersión")
plt.grid()
plt.show()

r, pvalue = stats.pearsonr(x, y)
print("r: ", r)

x_const = sm.add_constant(x)
modelo = sm.OLS(y, x_const).fit()

print(modelo.summary())
b0 = modelo.params[0]
b1 = modelo.params[1]
print("Ecuación:")
print(f"Y = {b0:.2f} + {b1:.2f}X")

plt.scatter(x, y)
plt.plot(x, b0 + b1*x)
plt.grid()
plt.show()

print(conf_int)

res = modelo.resid
plt.scatter(x, res)
plt.axhline(y=0)
plt.title("Residuales vs X")
plt.grid()
plt.show()

print("Shapiro:", shapiro_test)
print("Breusch-Pagan:", bp_test)

X_new = np.array([6,10,13])
X_new_const = sm.add_constant(X_new)
pred = modelo.predict(X_new_const)

print("Predicciones:")
for xi, yi in zip(X_new, predicciones):
    print(f"Para X={xi}, Y estimado={yi:.2f}")


data = pd.DataFrame({'X': x, 'Y': y})
modelo_formula = smf.ols('Y ~ X', data=data).fit()
anova = sm.stats.anova_lm(modelo_formula, typ=2)
print(anova)
# Out:
# r:  -0.8801262960169057
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.775
# Model:                            OLS   Adj. R-squared:                  0.756
# Method:                 Least Squares   F-statistic:                     41.24
# Date:                Thu, 16 Apr 2026   Prob (F-statistic):           3.29e-05
# Time:                        16:39:27   Log-Likelihood:                -40.988
# No. Observations:                  14   AIC:                             85.98
# Df Residuals:                      12   BIC:                             87.25
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         47.4876      3.571     13.299      0.000      39.708      55.267
# x1            -2.9587      0.461     -6.422      0.000      -3.962      -1.955
# ==============================================================================
# Omnibus:                        0.532   Durbin-Watson:                   2.507
# Prob(Omnibus):                  0.766   Jarque-Bera (JB):                0.443
# Skew:                          -0.366   Prob(JB):                        0.801
# Kurtosis:                       2.526   Cond. No.                         21.5
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Ecuación:
# Y = 47.49 + -2.96X
# [[ 6.44199691 42.61164624]
#  [ 0.41921868  0.86714104]]
# Shapiro: ShapiroResult(statistic=np.float64(0.9731638066576076), pvalue=np.float64(0.901827735700704))
# Breusch-Pagan: (np.float64(1.4477631507186295), np.float64(0.2288872132755837), np.float64(1.3887685972917598), np.float64(0.25973450207912396))
# Predicciones:
# Para X=6, Y estimado=69.55
# Para X=10, Y estimado=72.77
# Para X=13, Y estimado=78.55
#               sum_sq    df          F    PR(>F)
# X         983.548996   1.0  41.243954  0.000033
# Residual  286.165289  12.0        NaN       NaN

# %% [markdown]
# ### Problema 3
# A menudo, quienes hacen la contabilidad de costos estiman los gastos generales con base en el nivel de producción. En Standard Knitting Co. han reunido información acerca de los gastos generales y las unidades producidas en diferentes plantas.
#
# | Gastos generales | 191 | 170 | 272 | 155 | 280 | 173 | 234 | 116 | 153 | 178 |
# |------------------|-----|-----|-----|-----|-----|-----|-----|-----|-----|-----|
# | Unidades        |  40 |  42 |  53 |  35 |  56 |  39 |  48 |  30 |  37 |  40 |
#
# 1.   Establesca una variable dependiente ($Y$) y una variable independiente ($X$).
# 2.   Realice un diagrama de dispersión para estos datos.
# 3. ¿Los datos soportan la suposición de linealidad?
# 4. Calcule el coeficiente de correlación e interprete el resultado.
# 5. Calcule el coeficiente de determinación e interprete el resultado.
# 6. Obtenga la recta de regresión ajustada y grafíquelo sobre el gráfico de dispersión.
# 7. Obtenga un intervalo de confianza del 95% para la pendiente de la recta de regresión ajustada ($b_1$)
# 8. Calcule los residuales y trace un nuevo gráfico de dispersión. Comente, ¿Parece que se verifican los supuestos?
# 9. Realice la prueba de Shapiro para los residuales y comente el resultado.
# 10. Realice la prueba de Brausch-Pagan para los residuales y comente el resultado.
# 11. Utiliza la recta de regresión para interpolar dos valores y extrapolar uno. Comenta estos resultados.
# 12. Realice una tabla ANOVA e interprete el resultado.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import statsmodels.stats.api as sms
import statsmodels.api as sm
import statsmodels.formula.api as smf
import scipy.stats as stats

x = np.array([40,42,53,35,56,39,48,30,37,40])
y = np.array([191,170,272,155,280,173,234,116,153,178])

plt.scatter(x,y)
plt.xlabel("unidaades")
plt.ylabel("Gastos")
plt.title("Diagrama de dispersión")
plt.grid()
plt.show()

r, pvalue = stats.pearsonr(x, y)
print("r: ", r)

x_const = sm.add_constant(x)
modelo = sm.OLS(y, x_const).fit()

print(modelo.summary())

b0 = modelo.params[0]
b1 = modelo.params[1]
print(f"Y = {b0:.2f} + {b1:.2f}X")

plt.scatter(x, y)
plt.plot(x, b0 + b1*x)
plt.grid()
plt.show()

print(modelo.conf_int())

res = modelo.resid
plt.scatter(x, res)
plt.axhline(y=0)
plt.show()

print("Shapiro:",stats.shapiro(res))
print("Breusch-Pagan:", sms.het_breuschpagan(res, x_const))

X_new = np.array([38,45,60])
X_new_const = sm.add_constant(X_new)
pred = modelo.predict(X_new_const)

for xi, yi in zip(X_new, pred):
    print(f"X={xi}, Y={yi:.2f}")

data = pd.DataFrame({'X': x, 'Y': y})
modelo_formula = smf.ols('Y ~ X', data=data).fit()
anova = sm.stats.anova_lm(modelo_formula, typ=2)
print(anova)
# Out:
# r:  0.9835155492696092
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.967
# Model:                            OLS   Adj. R-squared:                  0.963
# Method:                 Least Squares   F-statistic:                     236.7
# Date:                Thu, 16 Apr 2026   Prob (F-statistic):           3.17e-07
# Time:                        19:32:11   Log-Likelihood:                -36.329
# No. Observations:                  10   AIC:                             76.66
# Df Residuals:                       8   BIC:                             77.26
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const        -80.4429     18.015     -4.465      0.002    -121.986     -38.899
# x1             6.4915      0.422     15.384      0.000       5.518       7.465
# ==============================================================================
# Omnibus:                        6.407   Durbin-Watson:                   2.794
# Prob(Omnibus):                  0.041   Jarque-Bera (JB):                2.374
# Skew:                          -1.104   Prob(JB):                        0.305
# Kurtosis:                       3.906   Cond. No.                         238.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Y = -80.44 + 6.49X
# [[-121.98637284  -38.89934145]
#  [   5.51844978    7.46454342]]
# Shapiro: ShapiroResult(statistic=np.float64(0.9002438537213353), pvalue=np.float64(0.22045077017698533))
# Breusch-Pagan: (np.float64(0.00031538771596117954), np.float64(0.9858309862929234), np.float64(0.00025231813057312574), np.float64(0.9877155207348176))
# X=38, Y=166.23
# X=45, Y=211.67
# X=60, Y=309.05
#                 sum_sq   df           F        PR(>F)
# X         24778.042517  1.0  236.669535  3.167080e-07
# Residual    837.557483  8.0         NaN           NaN

# %% [markdown]
# ### Problema 4
# Las ventas de línea blanca varían según el estado del mercado de casas nuevas: cuando las ventas de casas nuevas son buenas, también lo son las de lavaplatos, lavadoras de ropa, secadoras y refrigeradores.
# Una asociación de comercio compiló los siguientes datos históricos (en miles de unidades) de las ventas de línea blanca y la construcción de casas.
#
# | Construcción de casas (miles) | Ventas de línea blanca (miles) |
# |-------------------------------|--------------------------------|
# | 2.0                           | 5.0                            |
# | 2.5                           | 5.5                            |
# | 3.2                           | 6.0                            |
# | 3.6                           | 7.0                            |
# | 3.7                           | 7.2                            |
# | 4.0                           | 7.7                            |
# | 4.2                           | 8.4                            |
# | 4.6                           | 9.0                            |
# | 4.8                           | 9.7                            |
# | 5.0                           | 10.0                           |
#
# 1.   Establesca una variable dependiente ($Y$) y una variable independiente ($X$).
# 2.   Realice un diagrama de dispersión para estos datos.
# 3. ¿Los datos soportan la suposición de linealidad?
# 4. Calcule el coeficiente de correlación e interprete el resultado.
# 5. Calcule el coeficiente de determinación e interprete el resultado.
# 6. Obtenga la recta de regresión ajustada y grafíquelo sobre el gráfico de dispersión.
# 7. Obtenga un intervalo de confianza del 95% para la pendiente de la recta de regresión ajustada ($b_1$)
# 8. Calcule los residuales y trace un nuevo gráfico de dispersión. Comente, ¿Parece que se verifican los supuestos?
# 9. Realice la prueba de Shapiro para los residuales y comente el resultado.
# 10. Realice la prueba de Brausch-Pagan para los residuales y comente el resultado.
# 11. Utiliza la recta de regresión para interpolar dos valores y extrapolar uno. Comenta estos resultados.
# 12. Realice una tabla ANOVA e interprete el resultado.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import statsmodels.stats.api as sms
import statsmodels.api as sm
import statsmodels.formula.api as smf
import scipy.stats as stats

x = np.array([2.0,2.5,3.2,3.6,3.7,4.0,4.2,4.6,4.8,5.0])
y = np.array([5.0,5.5,6.0,7.0,7.2,7.7,8.4,9.0,9.7,10.0])

plt.scatter(x,y)
plt.xlabel("Construccion")
plt.ylabel("Ventas")
plt.title("Diagrama de dispersión")
plt.grid()
plt.show()

r, pvalue = stats.pearsonr(x, y)
print("r: ", r)

x_const = sm.add_constant(x)
modelo = sm.OLS(y, x_const).fit()

print(modelo.summary())

b0 = modelo.params[0]
b1 = modelo.params[1]
print(f"Y = {b0:.2f} + {b1:.2f}X")

plt.scatter(x, y)
plt.plot(x, b0 + b1*x)
plt.grid()
plt.show()

print(modelo.conf_int())

res = modelo.resid
plt.scatter(x, res)
plt.axhline(y=0)
plt.show()

print("Shapiro:",stats.shapiro(res))
print("Breusch-Pagan:", sms.het_breuschpagan(res, x_const))

X_new = np.array([3.0,4.5,6.0])
X_new_const = sm.add_constant(X_new)
pred = modelo.predict(X_new_const)

for xi, yi in zip(X_new, pred):
    print(f"X={xi}, Y={yi:.2f}")

data = pd.DataFrame({'X': x, 'Y': y})
modelo_formula = smf.ols('Y ~ X', data=data).fit()
anova = sm.stats.anova_lm(modelo_formula, typ=2)
print(anova)
# Out:
# r:  0.9807739021534332
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.962
# Model:                            OLS   Adj. R-squared:                  0.957
# Method:                 Least Squares   F-statistic:                     202.1
# Date:                Thu, 16 Apr 2026   Prob (F-statistic):           5.84e-07
# Time:                        19:36:46   Log-Likelihood:                -2.8166
# No. Observations:                  10   AIC:                             9.633
# Df Residuals:                       8   BIC:                             10.24
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          1.0168      0.473      2.148      0.064      -0.075       2.108
# x1             1.7376      0.122     14.215      0.000       1.456       2.019
# ==============================================================================
# Omnibus:                        0.311   Durbin-Watson:                   0.975
# Prob(Omnibus):                  0.856   Jarque-Bera (JB):                0.433
# Skew:                          -0.138   Prob(JB):                        0.806
# Kurtosis:                       2.019   Cond. No.                         17.2
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Y = 1.02 + 1.74X
# [[-0.07484828  2.10836757]
#  [ 1.45569318  2.01943467]]
# Shapiro: ShapiroResult(statistic=np.float64(0.9655068028925919), pvalue=np.float64(0.8463507249054649))
# Breusch-Pagan: (np.float64(1.9919288681821201), np.float64(0.15813934528309412), np.float64(1.9899212535890052), np.float64(0.19602874795147224))
# X=3.0, Y=6.23
# X=4.5, Y=8.84
# X=6.0, Y=11.44
#              sum_sq   df           F        PR(>F)
# X         25.976581  1.0  202.069951  5.841003e-07
# Residual   1.028419  8.0         NaN           NaN

# %% [markdown]
# ### Problema 5
# William C. Andrews, consultor de comportamiento organizacional de Victory Motorcycles, ha diseñado una prueba para mostrar a los supervisores de la compañía los peligros de sobrevigilar a sus trabajadores.
# Un trabajador de la línea de ensamble tiene a su cargo una serie de tareas complicadas. Durante el desempeño del trabajador, un inspector lo interrumpe constantemente para ayudarlo a terminar las tareas.
# El trabajador, después de terminar su trabajo, recibe una prueba psicológica diseñada para medir la hostilidad del trabajador hacia la autoridad
# (una alta puntuación implica una hostilidad baja). A ocho distintos trabajadores se les asignaron las tareas y luego se les interrumpió para darles instrucciones útiles un número variable de veces (línea X).
# Sus calificaciones en la prueba de hostilidad se dan en el renglón Y.
#
# | número interrupciones al trabajador |  5  | 10  | 10  | 15  | 15  | 20  | 20  | 25  |
# |-----------------------------------------|----|----|----|----|----|----|----|----|
# | calificación del trabajador en la prueba de hostilidad | 58  | 41  | 45  | 27  | 26  | 12  | 16  |  3  |
#
# 1.   Establesca una variable dependiente ($Y$) y una variable independiente ($X$).
# 2.   Realice un diagrama de dispersión para estos datos.
# 3. ¿Los datos soportan la suposición de linealidad?
# 4. Calcule el coeficiente de correlación e interprete el resultado.
# 5. Calcule el coeficiente de determinación e interprete el resultado.
# 6. Obtenga la recta de regresión ajustada y grafíquelo sobre el gráfico de dispersión.
# 7. Obtenga un intervalo de confianza del 95% para la pendiente de la recta de regresión ajustada ($b_1$)
# 8. Calcule los residuales y trace un nuevo gráfico de dispersión. Comente, ¿Parece que se verifican los supuestos?
# 9. Realice la prueba de Shapiro para los residuales y comente el resultado.
# 10. Realice la prueba de Brausch-Pagan para los residuales y comente el resultado.
# 11. Utiliza la recta de regresión para interpolar dos valores y extrapolar uno. Comenta estos resultados.
# 12. Realice una tabla ANOVA e interprete el resultado.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import statsmodels.stats.api as sms
import statsmodels.api as sm
import statsmodels.formula.api as smf
import scipy.stats as stats

x = np.array([5,10,10,15,15,20,20,25])
y = np.array([58,41,45,27,26,12,16,3])

plt.scatter(x,y)
plt.xlabel("Inerrupciones")
plt.ylabel("Hostilidad")
plt.title("Diagrama de dispersión")
plt.grid()
plt.show()

r, pvalue = stats.pearsonr(x, y)
print("r: ", r)

x_const = sm.add_constant(x)
modelo = sm.OLS(y, x_const).fit()

print(modelo.summary())

b0 = modelo.params[0]
b1 = modelo.params[1]
print(f"Y = {b0:.2f} + {b1:.2f}X")

plt.scatter(x, y)
plt.plot(x, b0 + b1*x)
plt.grid()
plt.show()

print(modelo.conf_int())

res = modelo.resid
plt.scatter(x, res)
plt.axhline(y=0)
plt.show()

print("Shapiro:",stats.shapiro(res))
print("Breusch-Pagan:", sms.het_breuschpagan(res, x_const))

X_new = np.array([12,18,30])
X_new_const = sm.add_constant(X_new)
pred = modelo.predict(X_new_const)

for xi, yi in zip(X_new, pred):
    print(f"X={xi}, Y={yi:.2f}")

data = pd.DataFrame({'X': x, 'Y': y})
modelo_formula = smf.ols('Y ~ X', data=data).fit()
anova = sm.stats.anova_lm(modelo_formula, typ=2)
print(anova)
# Out:
# r:  -0.9928495402404849
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.986
# Model:                            OLS   Adj. R-squared:                  0.983
# Method:                 Least Squares   F-statistic:                     415.1
# Date:                Thu, 16 Apr 2026   Prob (F-statistic):           9.09e-07
# Time:                        19:40:49   Log-Likelihood:                -17.139
# No. Observations:                   8   AIC:                             38.28
# Df Residuals:                       6   BIC:                             38.44
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         70.5000      2.227     31.661      0.000      65.051      75.949
# x1            -2.8000      0.137    -20.373      0.000      -3.136      -2.464
# ==============================================================================
# Omnibus:                        4.762   Durbin-Watson:                   1.735
# Prob(Omnibus):                  0.092   Jarque-Bera (JB):                1.054
# Skew:                          -0.000   Prob(JB):                        0.590
# Kurtosis:                       1.221   Cond. No.                         43.0
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Y = 70.50 + -2.80X
# [[65.05138422 75.94861578]
#  [-3.13629587 -2.46370413]]
# Shapiro: ShapiroResult(statistic=np.float64(0.8266756414454115), pvalue=np.float64(0.054816491127669634))
# Breusch-Pagan: (np.float64(1.3333333333332522), np.float64(0.24821307898993467), np.float64(1.1999999999999127), np.float64(0.3153335962012458))
# X=12, Y=36.90
# X=18, Y=20.10
# X=30, Y=-13.50
#           sum_sq   df           F        PR(>F)
# X         2352.0  1.0  415.058824  9.090964e-07
# Residual    34.0  6.0         NaN           NaN
